# %%
# !pip install pycognaize
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.2/110.2 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.2/677.2 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 666.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 42.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 5.9 MB/s eta 0:00:00
# ...

# %%
from pycognaize import Snapshot

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
import os

# Note the use of double backslashes to escape the single backslashes in the paths
os.environ['SNAPSHOT_PATH'] = "drive/My Drive"
os.environ['SNAPSHOT_ID'] = "65f297148880fe59a48b72ff"

# %%
snapshot = Snapshot.get()

# %%
snapshot.documents._ids
# Out:
# ['65e8201be6614c0011e39b72',
#  '65e8251ee6614c0011e4303a',
#  '65eef4d0e84186001138e3da',
#  '65eef8dae841860011394589']

# %%
document=snapshot.documents['65e8201be6614c0011e39b72']

# %%
document.x['current_year'][0].value
# Out:
# '02/28/2023'

# %%
for pythonname in document.y.keys():
  print(document.y[pythonname][0].value)
# Out:
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# nan
#
# nan
# ...

# %%
document.pages
# Out:
# OrderedDict([(1, <Page 1>),
#              (2, <Page 2>),
#              (3, <Page 3>),
#              (4, <Page 4>),
#              (5, <Page 5>),
#              (6, <Page 6>),
#              (7, <Page 7>),
#              (8, <Page 8>),
#              (9, <Page 9>),
#              (10, <Page 10>),
#              (11, <Page 11>),
#              (12, <Page 12>),
#              (13, <Page 13>),
#              (14, <Page 14>),
#              (15, <Page 15>),
#              (16, <Page 16>),
#              (17, <Page 17>),
#              (18, <Page 18>),
#              (19, <Page 19>),
#              (20, <Page 20>),
#              (21, <Page 21>)])

# %%
document.load_page_images()

# %%
document.load_page_ocr()

# %%
document.load_page_ocr(lambda page: page.page_number%2)

# %%
document.get_page_images()

# %%
page_8 = document.pages[8]

# %%
page_8.search_text('Inventories')
# Out:
# [{'top': 551,
#   'bottom': 568,
#   'left': 193,
#   'right': 310,
#   'matched_words': [{'left': 193,
#     'right': 310,
#     'top': 551,
#     'bottom': 568,
#     'ocr_text': 'Inventories',
#     'word_id_number': 46}]}]

# %%
image = page_8.draw_ocr_boxes()

# %%
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
document.y
# Out:
# FieldCollection([('c_endingretainedearnings_re__current',
#                   [<NumericField: Current value: >]),
#                  ('c_endingretainedearnings_re__previous',
#                   [<NumericField: Previous value: >]),
#                  ('c_endingretainedearnings_re__tr',
#                   [<TextField: Text representation: >]),
#                  ('c_begretearningsrestated_re__current',
#                   [<NumericField: Current value: >]),
#                  ('c_begretearningsrestated_re__previous',
#                   [<NumericField: Previous value: >]),
#                  ('c_begretearningsrestated_re__tr',
#                   [<TextField: Text representation: >]),
#                  ('v_beginningretainedearnings_re__current',
#                   [<NumericField: Current value: >]),
#                  ('v_beginningretainedearnings_re__previous',
#                   [<NumericField: Previous value: >]),
#                  ('v_beginningretainedearnings_re__tr',
# ...

# %%
document.x['table']
# Out:
# [<TableField: table>,
#  <TableField: Table>,
#  <TableField: table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: Table>,
#  <TableField: Table>]

# %%
table_field = document.x['table']

# %%
table_1 = table_field[0]

# %%
table_1
# Out:
# <TableField: table>

# %%
table_1_tags = table_1.tags[0]
table_1_tags
# Out:
# <TableTag: left: 12.07792573816636, right: 90.0, top: 13.0, bottom: 54.77272727272727>

# %%
table_1_tags.df
# Out:
#                                            0      1
# 0                                              Page
# 1                        General Information      2
# 2   Directors' Responsibilities and Approval      3
# 3                          Directors' Report      4
# 4         Report of the Independent Reviewer    5-6
# 5            Statement of Financial Position      7
# 6          Statement of Comprehensive Income      8
# 7             Statement of Changes in Equity      9
# 8                    Statement of Cash Flows     10
# 9                        Accounting Policies  11-13
# 10         Notes to the Financial Statements  14-18
# 11                Supplementary information:
# 12                 Detailed Income Statement  19-20

# %%
table_4 = table_field[3]

# %%
table_4_tags = table_4.tags[0]
print(type(table_4_tags))
# Out:
# <class 'pycognaize.document.tag.table_tag.TableTag'>

# %%
table_4_tags.df
# Out:
#                                                0      1           2  \
# 0   Statement of Financial Position Figures in R  Notes        2023
# 1                                         Assets
# 2                             Non-current assets
# 3                  Property, plant and equipment      2  40,305,579
# 4                                 Current assets
# 5                                    Inventories          1,089,091
# 6                    Trade and other receivables      3   6,838,506
# 7                      Cash and cash equivalents      4     750,088
# 8                           Total current assets          8,677,685
# 9                                   Total assets         48,983,264
# 10                        Equity and liabilities
# 11                                        Equity
# 12                                Issued capital      5         100
# 13                               Retained income          6,427,552
# ...

# %%
excel_file_path = '/content/drive/My Drive/table_4_tags.xlsx'
table_4_tags.df.to_excel(excel_file_path, index=False)

# %%
from google.colab import files

files.download('/content/drive/My Drive/table_4_tags.xlsx')

# %%
document.pages
# Out:
# OrderedDict([(1, <Page 1>),
#              (2, <Page 2>),
#              (3, <Page 3>),
#              (4, <Page 4>),
#              (5, <Page 5>),
#              (6, <Page 6>),
#              (7, <Page 7>),
#              (8, <Page 8>),
#              (9, <Page 9>),
#              (10, <Page 10>),
#              (11, <Page 11>),
#              (12, <Page 12>),
#              (13, <Page 13>),
#              (14, <Page 14>),
#              (15, <Page 15>),
#              (16, <Page 16>),
#              (17, <Page 17>),
#              (18, <Page 18>),
#              (19, <Page 19>),
#              (20, <Page 20>),
#              (21, <Page 21>)])
